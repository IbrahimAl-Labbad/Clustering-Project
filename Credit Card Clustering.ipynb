# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\AcTivE\Desktop\Project\Credit Card Clustering\CC GENERAL.csv')
df.head(10)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
# 7  C10008  1823.652743           1.000000     436.20              0.00
# 8  C10009  1014.926473           1.000000     861.49            661.49
# 9  C10010   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# ...

# %%
# Shape Of The Dataset
df.shape
# Out:
# (8950, 18)

# %%
# Some info of the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#Let's see what are the columns were given in the dataset
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.drop('CUST_ID', axis=1, inplace=True)

# %% [markdown]
# # Preprocessing

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer()

# %%
df['MINIMUM_PAYMENTS'] =imp.fit_transform(df[['MINIMUM_PAYMENTS']])

# %%
df['MINIMUM_PAYMENTS'].isnull().sum()
# Out:
# 0

# %%
df['CREDIT_LIMIT'].fillna(value=df['CREDIT_LIMIT'].mean(), inplace=True)

# %%
df['CREDIT_LIMIT'].isnull().sum()
# Out:
# 0

# %%
# checking the outliers in each column
for col in df.columns:
    
    fig, ax = plt.subplots(figsize=(7, 3))
    
    sns.boxplot(x=df[col], ax=ax)
   
    ax.set_title(col, fontsize=15)

    plt.show()

# %% [markdown]
# - Too MANY OUTLIERS
# - If we drop them, we'll lost so much data
# - We can assign a range of values in each column

# %%
df_range= df.copy()

# %%
outliers_features= ['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT']

# %%
# Remove outliers

def remove_outliers(df_range,outliers_features):
    # create copy of dataframe
    
    data = df_range.copy()
    
    for feature in data[outliers_features].columns:
        Q3 = data[feature].quantile(0.75)
        Q1 = data[feature].quantile(0.25)
        IQR = Q3 - Q1
        lower_limit = round(Q1 - 1.5 * IQR)
        upper_limit = round(Q3 + 1.5 * IQR)
        data.loc[data[feature]>= upper_limit,feature] = upper_limit
        data.loc[data[feature]<=lower_limit,feature] = lower_limit
#         data = data[(data[feature] < upper_limit) & (data[feature] > lower_limit)]
    return data

# %%
df_range = remove_outliers(df,outliers_features)

# %%
df_range.describe()
# Out:
#            BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# count  8950.000000             8950.0  8950.000000       8950.000000
# mean   1390.514625                1.0   737.160840        354.413316
# std    1537.551539                0.0   879.560687        511.940728
# min       0.000000                1.0     0.000000          0.000000
# 25%     128.281915                1.0    39.635000          0.000000
# 50%     873.385231                1.0   361.280000         38.000000
# 75%    2054.140036                1.0  1110.130000        577.405000
# max    4943.000000                1.0  2716.000000       1444.000000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               295.585568    672.520384             0.490351
# std                396.268585    998.623835             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
#  - There are columns with only one value. Let's exclude them.

# %%
# Deleting the columns

df_range.drop( columns = ['BALANCE_FREQUENCY'],inplace=True)
df_range.drop( columns = ['PRC_FULL_PAYMENT'],inplace=True)

# %%
df_range.head()
# Out:
#        BALANCE  PURCHASES  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# 0    40.900749      95.40              0.00                    95.4
# 1  3202.467416       0.00              0.00                     0.0
# 2  2495.148862     773.17            773.17                     0.0
# 3  1666.670542    1499.00           1444.00                     0.0
# 4   817.714335      16.00             16.00                     0.0
#
#    CASH_ADVANCE  PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0      0.000000             0.166667                    0.000000
# 1   2785.000000             0.000000                    0.000000
# 2      0.000000             1.000000                    1.000000
# 3    205.788017             0.083333                    0.083333
# 4      0.000000             0.083333                    0.083333
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# 0                          0.083333                0.000000                 0
# ...

# %%
# Heatmap

df_corr = df_range.corr()
f, ax = plt.subplots(figsize=(16, 10))

sns.heatmap(df_corr, annot=True, fmt='.2f', cmap='RdYlGn',annot_kws={'size': 10}, ax=ax)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_range)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
x_pca  = pca.fit_transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (8950, 15)

# %%
x_pca.shape
# Out:
# (8950, 2)

# %%
plt.figure(figsize=(15,10))
plt.scatter(x_pca[:,0],x_pca[:,1],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
x_pca
# Out:
# array([[-1.52728152, -2.28255874],
#        [-2.22880849,  2.6808024 ],
#        [ 1.39700274,  0.03013664],
#        ...,
#        [-0.66165407, -2.62255158],
#        [-2.60186726, -2.03409063],
#        [ 0.38180148, -0.73048887]])

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ### Finding the Optimal Number of Clusters (Elbow / Knee Method)

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(x_pca)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)

# %%
kmeans.fit(x_pca)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
kmeans.cluster_centers_
# Out:
# array([[-1.959506  ,  2.76984123],
#        [ 0.87274119, -1.24024981],
#        [ 3.76878727,  1.2812265 ],
#        [-1.68542734, -0.98833819]])

# %%
kmeans.inertia_
# Out:
# 19741.586635967757

# %%
y_kmeans = kmeans.fit_predict(x_pca)
y_kmeans
# Out:
# array([3, 0, 1, ..., 3, 3, 1])

# %%
plt.scatter(x_pca[:,0], x_pca[:,1], c=kmeans.labels_, cmap='rainbow')
plt.title('Mall Customers')
plt.xlabel('Annual Income (K$)')
plt.ylabel('Spending Score (1-100)')
plt.show()

# %%
Credit_Clustering  = df_range.copy()
Credit_Clustering['Clusters'] = y_kmeans
Credit_Clustering
# Out:
#           BALANCE  PURCHASES  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# 0       40.900749      95.40              0.00                   95.40
# 1     3202.467416       0.00              0.00                    0.00
# 2     2495.148862     773.17            773.17                    0.00
# 3     1666.670542    1499.00           1444.00                    0.00
# 4      817.714335      16.00             16.00                    0.00
# ...           ...        ...               ...                     ...
# 8945    28.493517     291.12              0.00                  291.12
# 8946    19.183215     300.00              0.00                  300.00
# 8947    23.398673     144.40              0.00                  144.40
# 8948    13.457564       0.00              0.00                    0.00
# 8949   372.708075    1093.25           1093.25                    0.00
#
#       CASH_ADVANCE  PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# ...

# %%
Credit_Clustering['Clusters'].unique()
# Out:
# array([3, 0, 1, 2])
